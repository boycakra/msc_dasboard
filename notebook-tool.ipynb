# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mplsoccer import Radar, FontManager
from ipywidgets import widgets, interact
file_path = 'Dummy.csv'
df = pd.read_csv(file_path, encoding='ISO-8859-1')

# %%
df
# Out:
#    Competition_id  Match_id     Stage Coordinates x Coordinates y  \
# 0        msc_2024     11001  Wildcard       (35.05%       29.70%)
# 1        msc_2024     11001  Wildcard       (30.69%       51.70%)
# 2        msc_2024     11001  Wildcard       (31.05%       50.70%)
# 3        msc_2024     11001  Wildcard       (18.69%       52.37%)
# 4        msc_2024     11001  Wildcard       (18.39%       50.70%)
# 5        msc_2024     11001  Wildcard       (19.02%       48.37%)
# 6        msc_2024     11001  Wildcard       (19.39%       47.03%)
# 7        msc_2024     11001  Wildcard       (33.72%       30.37%)
# 8        msc_2024     11001  Wildcard        (9.35%       23.37%)
# 9        msc_2024     11001  Wildcard       (10.39%       20.70%)
# 10       msc_2024     11001  Wildcard        (5.72%       26.90%)
# 11       msc_2024     11001  Wildcard       (72.72%       93.03%)
# 12       msc_2024     11001  Wildcard       (21.02%       47.57%)
# 13       msc_2024     11001  Wildcard       (21.05%       44.70%)
# 14       msc_2024     11001  Wildcard       (67.72%       70.37%)
# 15       msc_2024     11001  Wildcard       (49.69%       72.70%)
# 16       msc_2024     11001  Wildcard       (50.72%       68.37%)
# 17       msc_2024     11001  Wildcard       (40.72%       57.03%)
# 18       msc_2024     11001  Wildcard        (3.05%       44.10%)
# 19       msc_2024     11001  Wildcard       (44.39%       93.37%)
# 20       msc_2024     11001  Wildcard       (30.39%       69.30%)
# 21       msc_2024     11001  Wildcard       (69.05%       68.70%)
# 22       msc_2024     11001  Wildcard       (80.02%       69.30%)
# 23       msc_2024     11001  Wildcard       (79.39%       69.37%)
# 24       msc_2024     11001  Wildcard       (20.72%       78.37%)
# 25       msc_2024     11001  Wildcard       (27.35%       76.90%)
# 26       msc_2024     11001  Wildcard       (27.05%       78.70%)
# 27       msc_2024     11001  Wildcard       (26.72%       93.03%)
# 28       msc_2024     11001  Wildcard       (21.35%       64.37%)
# 29       msc_2024     11001  Wildcard       (19.72%       69.90%)
# 30       msc_2024     11001  Wildcard       (21.35%       67.97%)
# 31       msc_2024     11001  Wildcard       (20.72%       66.37%)
# 32       msc_2024     11001  Wildcard       (67.39%       69.70%)
# 33       msc_2024     11001  Wildcard        (6.72%       73.37%)
# 34       msc_2024     11001  Wildcard       (20.69%       85.03%)
# 35       msc_2024     11001  Wildcard       (17.39%       85.03%)
# 36       msc_2024     11001  Wildcard       (13.35%       86.63%)
# 37       msc_2024     11001  Wildcard       (13.72%       86.37%)
#
#                    Event           Event-Game  Event-player  \
# 0                 Turtle               Turtle          none
# 1       Death (Mid-lane)                Death      Mid-lane
# 2        Kill (Mid-lane)                 Kill      Mid-lane
# 3   Death (Jungler-line)                Death  Jungler-line
# 4    Kill (Jungler-line)                 Kill  Jungler-line
# 5        Kill (Exp-lane)                 Kill      Exp-lane
# 6   Death (Jungler-line)                Death  Jungler-line
# 7                 Turtle               Turtle          none
# 8       Death (Exp-lane)                Death      Exp-lane
# 9    Kill (Jungler-line)                 Kill  Jungler-line
# 10   Outer Tower Destroy  Outer Tower Destroy          none
# 11   Outer Tower Destroy  Outer Tower Destroy          none
# 12     Death (Gold-lane)                Death     Gold-lane
# 13   Kill (Jungler-line)                 Kill  Jungler-line
# 14                Turtle               Turtle          none
# 15  Death (Jungler-line)                Death  Jungler-line
# 16       Kill (Mid-lane)                 Kill      Mid-lane
# 17   Outer Tower Destroy  Outer Tower Destroy          none
# 18   Inner Tower Destroy  Inner Tower Destroy          none
# 19   Inner Tower Destroy  Inner Tower Destroy          none
# 20   Inner Tower Destroy  Inner Tower Destroy          none
# 21                  Lord                 Lord          none
# 22  Death (Jungler-line)                Death  Jungler-line
# 23   Kill (Jungler-line)                 Kill  Jungler-line
# 24    Base Tower Destroy   Base Tower Destroy          none
# 25      Death (Exp-lane)                Death      Exp-lane
# 26      Kill (Gold-lane)                 Kill     Gold-lane
# 27    Base Tower Destroy   Base Tower Destroy          none
# 28   Kill (Jungler-line)                 Kill  Jungler-line
# 29      Death (Mid-lane)                Death      Mid-lane
# 30      Kill (Gold-lane)                 Kill     Gold-lane
# 31  Death (Jungler-line)                Death  Jungler-line
# 32                  Lord                 Lord          none
# 33         Tower Destroy        Tower Destroy          none
# 34      Death (Exp-lane)                Death      Exp-lane
# 35      Kill (Gold-lane)                 Kill     Gold-lane
# 36      Kill (Gold-lane)                 Kill     Gold-lane
# 37  Death (Jungler-line)                Death  Jungler-line
#
#                    Team   Time
# 0             Alter Ego  10:43
# 1   Dewa United Esports  12:23
# 2             Alter Ego  12:23
# 3   Dewa United Esports  12:30
# 4             Alter Ego  12:30
# 5   Dewa United Esports  12:32
# 6             Alter Ego  12:32
# 7             Alter Ego  13:45
# 8   Dewa United Esports  13:56
# 9             Alter Ego  13:56
# 10            Alter Ego  14:14
# 11            Alter Ego  15:49
# 12  Dewa United Esports  16:04
# 13            Alter Ego  16:04
# 14            Alter Ego  16:44
# 15  Dewa United Esports  16:48
# 16            Alter Ego  16:48
# 17            Alter Ego  17:04
# 18            Alter Ego  17:46
# 19            Alter Ego  18:17
# 20            Alter Ego  18:43
# 21            Alter Ego  19:04
# 22  Dewa United Esports  19:14
# 23            Alter Ego  19:14
# 24            Alter Ego  19:41
# 25  Dewa United Esports  19:42
# 26            Alter Ego  19:42
# 27            Alter Ego  19:49
# 28  Dewa United Esports  20:23
# 29            Alter Ego  20:23
# 30  Dewa United Esports  20:26
# 31            Alter Ego  20:26
# 32            Alter Ego  22:22
# 33            Alter Ego  23:13
# 34  Dewa United Esports  23:26
# 35            Alter Ego  23:26
# 36  Dewa United Esports  23:31
# 37            Alter Ego  23:31
